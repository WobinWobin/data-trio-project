# %%
import pandas as pd

# %%
df = pd.read_csv('user_ratings.csv')
print(len(df.username.unique()))
# Out:
# 241

# %%
df
# Out:
#           username                     film_slug  rating
# 0         kurstboy                  michael-2026     2.0
# 1         kurstboy              mother-mary-2026     3.5
# 2         kurstboy           faces-of-death-2026     4.0
# 3         kurstboy  the-super-mario-galaxy-movie     1.5
# 4         kurstboy                     the-drama     4.0
# ...            ...                           ...     ...
# 502744  brianformo                river-of-grass     3.5
# 502745  brianformo                         fresh     3.0
# 502746  brianformo                   hoop-dreams     5.0
# 502747  brianformo                      erotique     1.5
# 502748  brianformo              dark-waters-1993     2.5
#
# [502749 rows x 3 columns]
