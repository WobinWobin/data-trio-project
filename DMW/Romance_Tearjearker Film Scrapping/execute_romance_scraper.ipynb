# %% [markdown]
# # CineMatch — Tristan's Scraper
# Runs `letterboxd_scraper.py` and shows the output CSVs when done.

# %%
# %pip install selenium webdriver-manager beautifulsoup4 pandas tqdm undetected-chromedriver
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run letterboxd_scraper.py
# Out:
# Starting browser...
#
# STEP 1: Collecting film URLs from lists
#
# Scraping list: Romance
#     Page 1: 72 items found, 72 films collected so far
#   72 films found
#
# Scraping list: Romance Classics
#     Page 1: 78 items found, 78 films collected so far
#   78 films found
#
# Scraping list: Tearjerkers
#     Page 1: 94 items found, 94 films collected so far
#   94 films found
#
# Scraping list: Saddest Films
#     Page 1: 50 items found, 50 films collected so far
#   50 films found
#
# romance_tears_lists.csv saved -- 294 rows
#
# STEP 2: Scraping 255 unique film pages
# Films: 100%|██████████| 255/255 [21:36<00:00,  5.09s/it]
# romance_tears_films.csv saved -- 255 rows
#
# Done. romance_tears_films.csv and romance_tears_lists.csv are ready to send.

# %% [markdown]
# ## Preview outputs

# %%
import pandas as pd
pd.read_csv("romance_tears_films.csv")
# Out:
#                                 film_title  year  \
# 0                               La La Land  2016
# 1    Eternal Sunshine of the Spotless Mind  2004
# 2               10 Things I Hate About You  1999
# 3                             Forrest Gump  1994
# 4                              Challengers  2024
# ..                                     ...   ...
# 250                                The Kid  1921
# 251                      Nothing in Common  1986
# 252                       The Elephant Man  1980
# 253                           The Wrestler  2008
# 254                        American Beauty  1999
#
#                              genre  runtime_mins  avg_rating  num_ratings  \
# 0             Drama|Comedy|Romance           129        4.12    4633643.0
# 1    Science Fiction|Romance|Drama           108        4.24    3455775.0
# 2             Comedy|Drama|Romance            97        4.05    3819636.0
# 3             Drama|Romance|Comedy           142        4.18    3828051.0
# ...

# %%
import pandas as pd
pd.read_csv("romance_tears_lists.csv")
# Out:
#          list_name                                           list_url  \
# 0          Romance  https://letterboxd.com/films/popular/genre/rom...
# 1          Romance  https://letterboxd.com/films/popular/genre/rom...
# 2          Romance  https://letterboxd.com/films/popular/genre/rom...
# 3          Romance  https://letterboxd.com/films/popular/genre/rom...
# 4          Romance  https://letterboxd.com/films/popular/genre/rom...
# ..             ...                                                ...
# 289  Saddest Films  https://letterboxd.com/icequeen86/list/the-50-...
# 290  Saddest Films  https://letterboxd.com/icequeen86/list/the-50-...
# 291  Saddest Films  https://letterboxd.com/icequeen86/list/the-50-...
# 292  Saddest Films  https://letterboxd.com/icequeen86/list/the-50-...
# 293  Saddest Films  https://letterboxd.com/icequeen86/list/the-50-...
#
#                                 film_title  \
# 0                               La La Land
# ...
