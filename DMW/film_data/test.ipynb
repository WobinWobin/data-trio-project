# %%
import pandas as pd
import json

# %%
# 1. Load the raw JSON data
with open('films.json', 'r') as f:
    raw_data = json.load(f)

# 2. Convert to DataFrame
# 'orient=index' treats keys (IDs) as rows
df = pd.DataFrame.from_dict(raw_data, orient='index')

# 3. Clean up the index
df.index.name = 'movie_id'
df.reset_index(inplace=True)

df
# Out:
#      movie_id                               name  \
# 0       34722                          Inception
# 1      251943  Spider-Man: Into the Spider-Verse
# 2       51896                    The Dark Knight
# 3      268950                        Baby Driver
# 4      209383                      Black Panther
# ...       ...                                ...
# 7862   267325                       Texas Rising
# 7863    78829                      Fort Massacre
# 7864   136178                 My Little Duckaroo
# 7865    79285                    I Want Him Dead
# 7866    24186                   The Trail Beyond
#
#                                           url     lid tmdb_id  \
# 0                            /film/inception/   34722   27205
# 1     /film/spider-man-into-the-spider-verse/  251943  324857
# 2                      /film/the-dark-knight/   51896     155
# 3                          /film/baby-driver/  268950  339403
# ...

# %%
# 1. Load the raw JSON data
with open('tmdb_film_details.json', 'r') as f:
    raw_data = json.load(f)

# 2. Convert to DataFrame
# 'orient=index' treats keys (IDs) as rows
df = pd.DataFrame.from_dict(raw_data, orient='index')

# 3. Clean up the index
df.index.name = 'movie_id'
df.reset_index(inplace=True)

df
# Out:
#      movie_id  release_decade  \
# 0       35234          1980.0
# 1      401394          2010.0
# 2       35230          1980.0
# 3      161278          2010.0
# 4      438511          2020.0
# ...       ...             ...
# 1649   610111             NaN
# 1650   307185             NaN
# 1651   143553             NaN
# 1652   412546             NaN
# 1653   447113             NaN
#
#                                    production_companies  \
# 0         [{'name': 'Troma Entertainment', 'id': 3052}]
# 1     [{'name': 'Genco', 'id': 17982}, {'name': 'RIM...
# 2     [{'name': 'Troma Entertainment', 'id': 3052}, ...
# 3     [{'name': 'Pop Films', 'id': 14531}, {'name': ...
# 4     [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# ...                                                 ...
# 1649                                                NaN
# 1650                                                NaN
# 1651                                                NaN
# ...
