# %% [markdown]
# # 🎬 Letterboxd + TMDB Film Scraper
#
# Scrapes film data from **Letterboxd** (ratings, likes, views, cast) and enriches it via the **TMDB v3 API** (runtime, budget, revenue, production info, franchise, etc.).
#
# ### Requirements
# ```bash
# pip install requests beautifulsoup4 lxml python-dateutil
# ```
#
# ### TMDB API Key
# Get a free key at [themoviedb.org/settings/api](https://www.themoviedb.org/settings/api) and paste it in the config cell below.

# %%
# Install dependencies (uncomment if needed)
# !pip install requests beautifulsoup4 lxml python-dateutil

# %% [markdown]
# ## 1 · Configuration

# %%
import os

# ─── Set your TMDB API key here ───────────────────────────────────────────
os.environ["TMDB_API_KEY"] = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2YmUzNzUzNGEzMWQ4OGUyZjgwMDgzNTE0ZjIxNTkxNCIsIm5iZiI6MTc3Nzg2NTYyMy41NTIsInN1YiI6IjY5ZjgxMzk3MzJiMjE4YzZlZjIzZTdlMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Ht28-i6lW7eZJu5HF3DiOvoNWd8ImpqEMIjRq6s4UPs"
# ──────────────────────────────────────────────────────────────────────────

# Output file for batch results
OUTPUT_FILE = "scraped_films.json"

# %% [markdown]
# ## 2 · Import the scraper module

# %%
from film_scraper import scrape_film, scrape_batch, TMDBClient
import json, pprint

# Create a shared client (reads TMDB_API_KEY from env)
client = TMDBClient()
print("TMDBClient ready ✓")
# Out:
# C:\Users\Robin\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.3)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# TMDBClient ready ✓

# %% [markdown]
# ## 3 · Scrape a single film

# %%
film = scrape_film(
    letterboxd_url="https://letterboxd.com/film/the-godfather/",
    tmdb_client=client,
)

pprint.pprint(film.to_dict())
# Out:
# 19:48:58  INFO      GET https://letterboxd.com/film/the-godfather/
# 19:49:00  INFO      GET https://letterboxd.com/film/the-godfather/members/
# 19:49:00  WARNING   Attempt 1 failed: 403 Client Error: Forbidden for url: https://letterboxd.com/film/the-godfather/members/
# 19:49:02  INFO      GET https://letterboxd.com/film/the-godfather/members/
# 19:49:03  WARNING   Attempt 2 failed: 403 Client Error: Forbidden for url: https://letterboxd.com/film/the-godfather/members/
# 19:49:08  INFO      GET https://letterboxd.com/film/the-godfather/members/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 film = scrape_film(
#       2     letterboxd_url="https://letterboxd.com/film/the-godfather/",
#       3     tmdb_client=client,
#       4 )
#       6 pprint.pprint(film.to_dict())
#
# ...

# %% [markdown]
# ### What each field means
#
# | Field | Source | Description |
# |---|---|---|
# | `lid` | Letterboxd | Internal Letterboxd film ID |
# | `avg_rating` | Letterboxd | Average rating out of 5 |
# | `number_of_ratings` | Letterboxd | Total ratings count |
# | `number_of_likes` | Letterboxd | Total likes |
# | `number_of_views` | Letterboxd | Total views / watches |
# | `genres` | Letterboxd | List of genre strings |
# | `director` | Letterboxd | Director slug (e.g. `francis-ford-coppola`) |
# | `actor` | Letterboxd | List of actor slugs |
# | `runtime` | TMDB | Runtime in minutes |
# | `release_year` / `release_decade` | TMDB | Computed from `release_date` |
# | `movie_age` | TMDB | Years since release |
# | `budget` / `revenue` / `profit` | TMDB | Box office figures (USD) |
# | `in_franchise` | TMDB | Part of a collection/franchise? |
# | `production_companies` | TMDB | `[{name, id}, ...]` |
# | `production_countries` | TMDB | List of country names (lowercase) |
# | `production_country_groups` | TMDB | Continents derived from countries |

# %% [markdown]
# ## 4 · Scrape a batch of films

# %%
# Add or remove films here
FILMS_TO_SCRAPE = [
    {"letterboxd_url": "https://letterboxd.com/film/the-godfather/"},
    {"letterboxd_url": "https://letterboxd.com/film/parasite-2019/"},
    {"letterboxd_url": "https://letterboxd.com/film/seven-samurai/"},
    {"letterboxd_url": "https://letterboxd.com/film/2001-a-space-odyssey/"},
    {"letterboxd_url": "https://letterboxd.com/film/mulholland-drive/"},
]

films = scrape_batch(
    FILMS_TO_SCRAPE,
    tmdb_client=client,
    delay_range=(2, 4),      # seconds between requests — be polite!
    output_file=OUTPUT_FILE,
)

print(f"\nScraped {len(films)} films → saved to {OUTPUT_FILE}")

# %% [markdown]
# ## 5 · Explore the results

# %%
# Quick summary table
print(f"{'Title':<35} {'Year':>4}  {'LB Rating':>9}  {'LB Views':>10}  {'Runtime':>7}  {'Budget':>12}")
print("-" * 85)
for f in films:
    title   = (f.name or "")[:34]
    year    = f.release_year or ""
    rating  = f"{f.avg_rating:.2f}" if f.avg_rating else "N/A"
    views   = f"{f.number_of_views:,}" if f.number_of_views else "N/A"
    runtime = f"{f.runtime}m" if f.runtime else "N/A"
    budget  = f"${f.budget:,}" if f.budget else "N/A"
    print(f"{title:<35} {str(year):>4}  {rating:>9}  {views:>10}  {runtime:>7}  {budget:>12}")

# %%
# Inspect one film in full
pprint.pprint(films[0].to_dict())

# %%
# Load the saved JSON file and inspect
with open(OUTPUT_FILE) as f:
    saved = json.load(f)

print(f"{len(saved)} films in {OUTPUT_FILE}")
print("Keys in first record:", list(saved[0].keys()))

# %% [markdown]
# ## 6 · Optional: load into pandas

# %%
import pandas as pd

df = pd.DataFrame([f.to_dict() for f in films])

# Columns available
print(df.columns.tolist())
df[["name", "release_year", "avg_rating", "number_of_views", "runtime", "budget", "in_franchise"]]

# %% [markdown]
# ## 7 · Advanced: TMDB-only (no Letterboxd scraping)

# %%
# If you already have the TMDB ID, you can skip Letterboxd entirely
film_tmdb_only = scrape_film(tmdb_id="238", tmdb_client=client)  # 238 = The Godfather
pprint.pprint(film_tmdb_only.to_dict())

# %% [markdown]
# ## 8 · Advanced: search TMDB by title

# %%
# Use the client directly to search for a TMDB ID by title
tmdb_id = client.search_movie("Parasite", year=2019)
print(f"TMDB ID for Parasite (2019): {tmdb_id}")

film_via_search = scrape_film(tmdb_id=tmdb_id, tmdb_client=client)
pprint.pprint(film_via_search.to_dict())
