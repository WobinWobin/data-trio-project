# %%
import pandas as pd
import json

# %%
# 1. Load the raw JSON data
with open('films.json', 'r') as f:
    raw_data = json.load(f)

# 2. Convert to DataFrame
# 'orient=index' treats keys (IDs) as rows
df = pd.DataFrame.from_dict(raw_data, orient='index')

# 3. Clean up the index
df.index.name = 'movie_id'
df.reset_index(inplace=True)

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 1. Load the raw JSON data
# ----> 2 with open('films.json', 'r') as f:
#       3     raw_data = json.load(f)
#       5 # 2. Convert to DataFrame
#       6 # 'orient=index' treats keys (IDs) as rows
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'films.json'
