# %% [markdown]
# # CineMatch — Disturbing / Horror Film Scraper
# Runs `letterboxd_scraper.py` and shows the output CSVs when done.

# %%
# %pip install selenium webdriver-manager beautifulsoup4 lxml pandas tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run letterboxd_scraper.py
# Out:
# Starting browser for list collection...
#
# STEP 1: Collecting film URLs from lists
#
# Scraping list: Popular Horror
#     [genre] Page 1: 72 items, 72 total
#   72 films found
#
# Scraping list: Popular Thriller
#   0 films found
#
# Scraping list: Most Disturbing
#   0 films found
#
# Scraping list: Horror Essentials
#   0 films found
#
# Scraping list: Psychological Horror
#   0 films found
#
# Scraping list: Extreme Cinema
#   0 films found
#
# disturbing_lists.csv saved -- 72 rows
#
# STEP 2: Scraping 72 unique film pages using 4 browsers in parallel
# Films: 100%|██████████| 72/72 [05:20<00:00,  4.45s/it]
# disturbing_films.csv saved -- 72 rows
#
# Done. disturbing_films.csv and disturbing_lists.csv are ready to send.

# %% [markdown]
# ## Preview outputs

# %%
import pandas as pd
pd.read_csv("disturbing_films.csv")
# Out:
#                       film_title  year                            genre  \
# 0                   The Exorcist  1973                     Horror|Drama
# 1                         Carrie  1976                  Horror|Thriller
# 2   The Texas Chain Saw Massacre  1974                           Horror
# 3                            Saw  2004             Crime|Mystery|Horror
# 4                  The Long Walk  2025  Horror|Science Fiction|Thriller
# ..                           ...   ...                              ...
# 67                     The Witch  2015                           Horror
# 68                         Split  2016                  Horror|Thriller
# 69                 28 Days Later  2002  Science Fiction|Horror|Thriller
# 70                28 Years Later  2025  Science Fiction|Thriller|Horror
# 71                       Heretic  2024                  Thriller|Horror
#
#     runtime_mins  avg_rating  num_ratings  num_reviews               country  \
# ...

# %%
import pandas as pd
pd.read_csv("disturbing_films.csv")
# Out:
#                       film_title  year                            genre  \
# 0                   The Exorcist  1973                     Horror|Drama
# 1                         Carrie  1976                  Horror|Thriller
# 2   The Texas Chain Saw Massacre  1974                           Horror
# 3                            Saw  2004             Crime|Mystery|Horror
# 4                  The Long Walk  2025  Horror|Science Fiction|Thriller
# ..                           ...   ...                              ...
# 67                     The Witch  2015                           Horror
# 68                         Split  2016                  Horror|Thriller
# 69                 28 Days Later  2002  Science Fiction|Horror|Thriller
# 70                28 Years Later  2025  Science Fiction|Thriller|Horror
# 71                       Heretic  2024                  Thriller|Horror
#
#     runtime_mins  avg_rating  num_ratings  num_reviews               country  \
# ...
