# %% [markdown]
# # CineMatch - Cinephile and Arthouse Scraper
# Runs `letterboxd_scraper.py` and shows the output CSVs when done.

# %%
# %pip install selenium beautifulsoup4 lxml pandas tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run letterboxd_scraper.py
# Out:
# Starting browser for list collection...
#
# STEP 1: Collecting film URLs from lists
#
# Scraping list: Cinephile Essentials
#     [genre] Page 1: 72 items, 72 total
#   72 films found
#
# Scraping list: Must See Cinema
#   0 films found
#
# Scraping list: Criterion
#   0 films found
#
# Scraping list: Arthouse
#   0 films found
#
# Scraping list: Cannes Palme dOr
#   0 films found
#
# Scraping list: Foreign Language
#   0 films found
#
# cinephileart_lists.csv saved -- 72 rows
#
# STEP 2: Scraping 72 unique film pages using 4 browsers in parallel
# Films: 100%|██████████| 72/72 [05:39<00:00,  4.71s/it]
# cinephileart_films.csv saved -- 72 rows
#
# Done. cinephileart_films.csv and cinephileart_lists.csv are ready to send.

# %% [markdown]
# ## Preview outputs

# %%
import pandas as pd
pd.read_csv("cinephileart_films.csv")
# Out:
#                   film_title  year                                 genre  \
# 0                Jojo Rabbit  2019                      War|Comedy|Drama
# 1                     Hamnet  2025                 History|Drama|Romance
# 2                       Soul  2020  Music|Drama|Family|Animation|Fantasy
# 3        Requiem for a Dream  2000                           Drama|Crime
# 4                      Drive  2011                  Thriller|Drama|Crime
# ..                       ...   ...                                   ...
# 67                    Wicked  2024                 Romance|Drama|Fantasy
# 68                     Anora  2024                  Drama|Romance|Comedy
# 69          Django Unchained  2012                         Drama|Western
# 70     The Devil Wears Prada  2006                          Comedy|Drama
# 71  The Shawshank Redemption  1994                           Crime|Drama
#
#     runtime_mins  avg_rating  num_ratings  num_reviews          country  \
# ...

# %%
import pandas as pd
pd.read_csv("cinephileart_lists.csv")
# Out:
#                list_name                                           list_url  \
# 0   Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 1   Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 2   Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 3   Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 4   Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# ..                   ...                                                ...
# 67  Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 68  Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 69  Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 70  Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
# 71  Cinephile Essentials  https://letterboxd.com/films/popular/genre/drama/
#
# ...
